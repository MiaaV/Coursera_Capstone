# %% [markdown]
# **Applied Data Science Capstone**

# %% [markdown]
# **_Clustering the neighborhoods in Toronto using k-means clustering approach_**

# %% [markdown]
# The notebook explores venues in Toronto's neighborhoods using Foursquare API and clusters these neighborhoods using the k-means algorithm.

# %% [markdown]
# The notebook is written based on the lab lesson in the Applied Data Science Capstone course.

# %%
import pandas as pd
import json 
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
import numpy as np

# %%
# importing the dataset
df = pd.read_csv('boroughs_toronto_with_coord.csv')

# %%
df.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
# keeping only boroughs that contain the word Toronto
for i in range(0,df.shape[0]):
    if 'Toronto' not in df.loc[i,'Borough']:
        df.drop(i, inplace=True)

# %%
df['Borough'].unique()
# Out:
# array(['East Toronto', 'Central Toronto', 'Downtown Toronto',
#        'West Toronto'], dtype=object)

# %%
df.head()
# Out:
#    PostalCode          Borough                    Neighborhood   Latitude  \
# 37        M4E     East Toronto                     The Beaches  43.676357
# 41        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 42        M4L     East Toronto  India Bazaar, The Beaches West  43.668999
# 43        M4M     East Toronto                 Studio District  43.659526
# 44        M4N  Central Toronto                   Lawrence Park  43.728020
#
#     Longitude
# 37 -79.293031
# 41 -79.352188
# 42 -79.315572
# 43 -79.340923
# 44 -79.388790

# %%
# finding the longitude and latitude of Toronto using geocoder
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode('Toronto, Canada')
latitude = location.latitude
longitude = location.longitude

print(f'The coordinates of Toronto are: ({latitude}, {longitude}).')
# Out:
# The coordinates of Toronto are: (43.6534817, -79.3839347).

# %%
# showing the map of Toronto with different neighborhoods marked.
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lon, bor, neighbor in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = f'Borough: {bor}, \nNeighborhood: {neighbor}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.5,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# Foursquare API
# After cell running, the creditentials are deleted due to the privacy purposes
CLIENT_ID = '' # Foursquare ID
CLIENT_SECRET = '' # Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
# the fuction returns a venues based on latitude and longitude values of a neighborhood
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# calling the previously defined function to explore the venues in Toronto
toronto_venues = getNearbyVenues(names=df['Neighborhood'], 
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude'])

# %%
print(f"The number of neighborhoods: {df['Neighborhood'].unique().shape[0]}")
print(f'The number of venues found: {toronto_venues.shape[0]}')
toronto_venues.head()
# Out:
# The number of neighborhoods: 38
# The number of venues found: 1573
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  The Beaches              43.676357              -79.293031
# 1  The Beaches              43.676357              -79.293031
# 2  The Beaches              43.676357              -79.293031
# 3  The Beaches              43.676357              -79.293031
# 4  The Beaches              43.676357              -79.293031
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0                   Glen Manor Ravine       43.676821       -79.293942
# 1  The Big Carrot Natural Food Market       43.678879       -79.297734
# 2                 Grover Pub and Grub       43.679181       -79.297215
# 3                       Upper Beaches       43.680563       -79.292869
# 4                 Seaspray Restaurant       43.678888       -79.298167
#
#       Venue Category
# 0              Trail
# 1  Health Food Store
# 2                Pub
# ...

# %%
# the number of venues in each neighborhood
toronto_venues.groupby('Neighborhood').count().iloc[:,0]
# Out:
# Neighborhood
# Berczy Park                                                                                                    60
# Brockton, Parkdale Village, Exhibition Place                                                                   24
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport     15
# Central Bay Street                                                                                             60
# Christie                                                                                                       16
# Church and Wellesley                                                                                           78
# Commerce Court, Victoria Hotel                                                                                100
# Davisville                                                                                                     33
# ...

# %%
print(f"The number of unique categories: {len(toronto_venues['Venue Category'].unique())}")
# Out:
# The number of unique categories: 233

# %%
# onehot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot.drop(['Neighborhood'], axis=1, inplace=True)
toronto_onehot.insert(0, "Neighborhood", list(toronto_venues['Neighborhood']), True)

# %%
# finding the frequency of occurrence of different venues in neighborhoods
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Adult Boutique  \
# 0                                         Berczy Park        0.000000
# 1        Brockton, Parkdale Village, Exhibition Place        0.000000
# 2   CN Tower, King and Spadina, Railway Lands, Har...        0.000000
# 3                                  Central Bay Street        0.000000
# 4                                            Christie        0.000000
# 5                                Church and Wellesley        0.012821
# 6                      Commerce Court, Victoria Hotel        0.000000
# 7                                          Davisville        0.000000
# 8                                    Davisville North        0.000000
# 9                        Dufferin, Dovercourt Village        0.000000
# 10                                     Enclave of M4L        0.000000
# 11                                     Enclave of M5E        0.000000
# ...

# %%
# function returns most common venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# top 10 most common venues in each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append(f'{ind+1}{indicators[ind]} Most Common Venue')
    except:
        columns.append(f'{ind+1}th Most Common Venue')

neighborhoods_venues = pd.DataFrame(columns=columns)
neighborhoods_venues['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 3                                 Central Bay Street           Coffee Shop
# 4                                           Christie         Grocery Store
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar                Bakery            Restaurant
# 1        Breakfast Spot           Coffee Shop           Yoga Studio
# 2      Airport Terminal         Boat or Ferry               Airport
# 3    Italian Restaurant        Sandwich Place                  Café
# 4                  Café                  Park             Nightclub
#
#   5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# ...

# %%
# clustering the neighborhoods in five clusters based on the frequency of different venues
k = 5
toronto_grouped_kmeans = toronto_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=k, random_state=0).fit(toronto_grouped_kmeans)

# %%
# adding clustering labels
neighborhoods_venues.insert(0, 'Cluster Labels', kmeans.labels_)

# merging df and neighborhood_venues to add postal code, borouh, latitude and longitude for each neighborhood
toronto_merged = df
toronto_merged = toronto_merged.join(neighborhoods_venues.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.head()
# Out:
#    PostalCode          Borough                    Neighborhood   Latitude  \
# 37        M4E     East Toronto                     The Beaches  43.676357
# 41        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 42        M4L     East Toronto  India Bazaar, The Beaches West  43.668999
# 43        M4M     East Toronto                 Studio District  43.659526
# 44        M4N  Central Toronto                   Lawrence Park  43.728020
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 37 -79.293031               2      Asian Restaurant     Health Food Store
# 41 -79.352188               2      Greek Restaurant           Coffee Shop
# 42 -79.315572               2                  Park        Sandwich Place
# 43 -79.340923               2           Coffee Shop               Brewery
# 44 -79.388790               0                  Park           Swim School
#
#    3rd Most Common Venue 4th Most Common Venue   5th Most Common Venue  \
# ...

# %%
# showing map with neighborhoods clustered
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Neihborhoods in each cluster:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1,2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough              Neighborhood  Cluster Labels  \
# 44   Central Toronto             Lawrence Park               0
# 50  Downtown Toronto                  Rosedale               0
# 64   Central Toronto  Forest Hill North & West               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 44                  Park           Swim School    Dim Sum Restaurant
# 50                  Park            Playground                 Trail
# 64                  Park                 Trail         Jewelry Store
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 44              Bus Line           Yoga Studio        Discount Store
# 50           Yoga Studio    Dim Sum Restaurant  Ethiopian Restaurant
# 64      Sushi Restaurant           Yoga Studio                 Diner
#
#    7th Most Common Venue 8th Most Common Venue        9th Most Common Venue  \
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1,2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough                 Neighborhood  Cluster Labels  \
# 48  Central Toronto  Moore Park, Summerhill East               1
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 48                   Gym                 Diner    Falafel Restaurant
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 48           Event Space  Ethiopian Restaurant           Escape Room
#
#    7th Most Common Venue        8th Most Common Venue 9th Most Common Venue  \
# 48     Electronics Store  Eastern European Restaurant   Dumpling Restaurant
#
#    10th Most Common Venue
# 48             Donut Shop

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1,2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough                                       Neighborhood  \
# 37      East Toronto                                        The Beaches
# 41      East Toronto                       The Danforth West, Riverdale
# 42      East Toronto                     India Bazaar, The Beaches West
# 43      East Toronto                                    Studio District
# 45   Central Toronto                                   Davisville North
# 46   Central Toronto                                 North Toronto West
# 47   Central Toronto                                         Davisville
# 49   Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 51  Downtown Toronto                        St. James Town, Cabbagetown
# 52  Downtown Toronto                               Church and Wellesley
# 53  Downtown Toronto                          Regent Park, Harbourfront
# 54  Downtown Toronto                           Garden District, Ryerson
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1,2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough Neighborhood  Cluster Labels 1st Most Common Venue  \
# 63  Central Toronto     Roselawn               3  Fast Food Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 63          Home Service                Garden    Dim Sum Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 63           Event Space  Ethiopian Restaurant           Escape Room
#
#    8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 63     Electronics Store  Eastern European Restaurant    Dumpling Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1,2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough                                       Neighborhood  \
# 68  Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Har...
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 68               4       Airport Service      Airport Terminal
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 68         Boat or Ferry               Airport    Airport Food Court
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 68        Airport Lounge      Sculpture Garden              Boutique
#
#    9th Most Common Venue 10th Most Common Venue
# 68       Harbor / Marina    Rental Car Location
